# %% [markdown]
# # PerOmics Supervised Optimization (Optuna)
#
# **Objective:** Optimize hyperparameters for direct supervised training (No Pretraining) to maximize classification classification performance on small, imbalanced multi-omics data (205 samples, 4 classes).
#
# **Workflow:**
# 1.  **Define Architecture:** Masked Encoders + Gated Attention Fusion + Focal Loss.
# 2.  **Optuna Tuning:** Run 50 trials of 5-Fold Cross-Validation to find robust hyperparameters.
# 3.  **Final Evaluation:** Train with best parameters and report detailed metrics (F1, Precision, Recall).
# 4.  **Save Results:** Export best parameters and metrics to CSVs.

# %%
import sys
import os
import pandas as pd
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.impute import KNNImputer
from sklearn.metrics import (
    f1_score, precision_score, recall_score, 
    accuracy_score, classification_report, confusion_matrix
)
import optuna
import warnings
warnings.filterwarnings('ignore')

# Check for GPU
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f">>> Running on: {DEVICE}")

# Reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
# Out:
# >>> Running on: cuda

# %%
class PerOmicCMAE(nn.Module):
    """Per-Omic Contrastive Masked Autoencoder (Encoder Only used for Supervised)"""
    
    def __init__(self, input_dim, latent_dim=64, hidden_dim=256, dropout_encoder=0.0):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim), 
            nn.GELU(),
            nn.Dropout(dropout_encoder),
            nn.Linear(hidden_dim, latent_dim)
        )

    def forward(self, x, noise_level=0.0, noise_type='gaussian', encode_only=True):
        # Noise Injection / Masking during training for robustness
        if self.training and noise_level > 0:
            if noise_type == 'gaussian':
                noise = torch.randn_like(x) * noise_level
                x_corrupted = x + noise
            elif noise_type == 'uniform':
                noise = (torch.rand_like(x) - 0.5) * 2 * noise_level
                x_corrupted = x + noise
            elif noise_type == 'dropout':
                mask = torch.bernoulli(torch.ones_like(x) * (1 - noise_level))
                x_corrupted = x * mask
            else:
                x_corrupted = x
        else:
            x_corrupted = x

        z = self.encoder(x_corrupted)
        return None, None, z, x_corrupted


class GatedAttentionFusion(nn.Module):
    """Gated Attention Fusion for multi-omics"""
    def __init__(self, latent_dim=64, num_classes=4, dropout_rate=0.3, hidden_dim=64):
        super().__init__()
        self.gate_rna = nn.Linear(latent_dim, 1)
        self.gate_meth = nn.Linear(latent_dim, 1)
        self.gate_clin = nn.Linear(latent_dim, 1) 
        self.classifier = nn.Sequential(
            nn.Linear(latent_dim * 3, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim, num_classes)
        )
        self.drop_rate = dropout_rate

    def forward(self, z_rna, z_meth, z_clin, apply_dropout=False):
        if apply_dropout and self.training:
            # Modality Dropout (regularization)
            if torch.rand(1).item() < self.drop_rate: z_rna = torch.zeros_like(z_rna)
            if torch.rand(1).item() < self.drop_rate: z_meth = torch.zeros_like(z_meth)
            if torch.rand(1).item() < self.drop_rate: z_clin = torch.zeros_like(z_clin)

        w_rna = torch.sigmoid(self.gate_rna(z_rna))
        w_meth = torch.sigmoid(self.gate_meth(z_meth))
        w_clin = torch.sigmoid(self.gate_clin(z_clin))

        z_fused = torch.cat([w_rna * z_rna, w_meth * z_meth, w_clin * z_clin], dim=1)
        
        return self.classifier(z_fused), torch.cat([w_rna, w_meth, w_clin], dim=1), z_fused


class FocalLoss(nn.Module):
    """Focal Loss for imbalanced classification"""
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_weight = (1 - pt) ** self.gamma
        focal_loss = focal_weight * ce_loss
        
        if self.alpha is not None:
            if isinstance(self.alpha, (float, int)):
                alpha_t = self.alpha
            else:
                if self.alpha.device != inputs.device:
                    self.alpha = self.alpha.to(inputs.device)
                alpha_t = self.alpha.gather(0, targets)
            focal_loss = alpha_t * focal_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
def load_raw_aligned_data():
    print(f"\n>>> LOADING RAW ALIGNED DATA")
    pheno_path = "Data/phenotype_clean.csv"
    if not os.path.exists(pheno_path):
        raise FileNotFoundError(f"{pheno_path} not found.")

    pheno = pd.read_csv(pheno_path, index_col=0)
    SUBTYPES_OF_INTEREST = [
        'Leiomyosarcoma, NOS', 'Dedifferentiated liposarcoma',
        'Undifferentiated sarcoma', 'Fibromyxosarcoma'
    ]
    col_name = 'primary_diagnosis.diagnoses'
    mask = pheno[col_name].isin(SUBTYPES_OF_INTEREST)
    pheno = pheno[mask]

    def load_omic(path, name):
        if not os.path.exists(path):
            _, _ = name, path # Unused
            return None
        df = pd.read_csv(path, index_col=0)
        df = df.T  # samples x features
        return df

    rna = load_omic("Data/expression_log.csv", "RNA")
    meth = load_omic("Data/methylation_mvalues.csv", "Methylation")
    cnv = load_omic("Data/cnv_log.csv", "CNV")

    common_samples = pheno.index.intersection(rna.index).intersection(meth.index).intersection(cnv.index)
    print(f"  Common Samples: {len(common_samples)}")

    pheno = pheno.loc[common_samples]
    rna = rna.loc[common_samples]
    meth = meth.loc[common_samples]
    cnv = cnv.loc[common_samples]

    le = LabelEncoder()
    Y = le.fit_transform(pheno[col_name])
    
    # Calculate Class Weights
    class_counts = np.bincount(Y)
    class_weights = len(Y) / (len(class_counts) * class_counts)
    class_weights = class_weights / class_weights.sum()
    
    return rna, meth, cnv, Y, le.classes_, class_weights

def prepare_fold_data(train_df, val_df, max_features=5000):
    tr_vals = train_df.values
    val_vals = val_df.values
    
    # 1. Variance Filter (Fit on Train only)
    if tr_vals.shape[1] > max_features:
        variances = np.nanvar(tr_vals, axis=0)
        top_indices = np.argpartition(variances, -max_features)[-max_features:]
        tr_vals = tr_vals[:, top_indices]
        val_vals = val_vals[:, top_indices]

    # 2. KNN Imputation (Fit on Train)
    imputer = KNNImputer(n_neighbors=5)
    tr_imp = imputer.fit_transform(tr_vals)
    val_imp = imputer.transform(val_vals)
    
    # 3. Scaling (Fit on Train)
    scaler = StandardScaler()
    tr_scaled = scaler.fit_transform(tr_imp)
    val_scaled = scaler.transform(val_imp)
    
    return (
        torch.FloatTensor(tr_scaled).to(DEVICE),
        torch.FloatTensor(val_scaled).to(DEVICE),
        tr_scaled.shape[1]
    )

# %%
def objective(trial):
    # --- 1. Hyperparameters to Tune ---
    params = {
        'latent_dim': trial.suggest_categorical('latent_dim', [16, 24, 32]),
        'hidden_dim': trial.suggest_categorical('hidden_dim', [96, 128]),
        'fusion_hidden_dim': trial.suggest_categorical('fusion_hidden_dim', [32, 48, 64]),
        'dropout_encoder': trial.suggest_float('dropout_encoder', 0.2, 0.5),
        'dropout_rate': trial.suggest_float('dropout_rate', 0.2, 0.5),
        'lr_fine': trial.suggest_float('lr_fine', 1e-5, 1e-3, log=True),
        'weight_decay': trial.suggest_float('weight_decay', 1e-5, 1e-3, log=True),
        'noise_level': trial.suggest_float('noise_level', 0.0, 0.3),
        'focal_gamma': trial.suggest_float('focal_gamma', 1.0, 6.0),
        'alpha_scale': trial.suggest_float('alpha_scale', 1.0, 3.0) # Scaling factor for class weights
    }

    # --- 2. Cross Validation Loop ---
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    fold_f1s = []

    # We iterate manually to keep data prep efficient
    for fold, (train_idx, val_idx) in enumerate(kf.split(rna_df, Y)):
        
        # Data Prep (Variance Filter -> Impute -> Scale)
        # NOTE: To speed up optimization, consider filtering ONCE globally if features are stable,
        # but for rigor we do it per fold.
        t_r_tr, t_r_val, dim_r = prepare_fold_data(rna_df.iloc[train_idx], rna_df.iloc[val_idx])
        t_m_tr, t_m_val, dim_m = prepare_fold_data(meth_df.iloc[train_idx], meth_df.iloc[val_idx])
        t_c_tr, t_c_val, dim_c = prepare_fold_data(cnv_df.iloc[train_idx], cnv_df.iloc[val_idx])
        
        t_y_tr = torch.LongTensor(Y[train_idx]).to(DEVICE)
        t_y_val = torch.LongTensor(Y[val_idx]).to(DEVICE)
        
        # Model Init
        encoder_r = PerOmicCMAE(dim_r, params['latent_dim'], params['hidden_dim'], params['dropout_encoder']).to(DEVICE)
        encoder_m = PerOmicCMAE(dim_m, params['latent_dim'], params['hidden_dim'], params['dropout_encoder']).to(DEVICE)
        encoder_c = PerOmicCMAE(dim_c, params['latent_dim'], params['hidden_dim'], params['dropout_encoder']).to(DEVICE)
        fusion = GatedAttentionFusion(params['latent_dim'], len(class_names), params['dropout_rate'], params['fusion_hidden_dim']).to(DEVICE)
        
        optimizer = optim.AdamW(
            list(encoder_r.parameters()) + list(encoder_m.parameters()) + 
            list(encoder_c.parameters()) + list(fusion.parameters()),
            lr=params['lr_fine'], weight_decay=params['weight_decay']
        )
        
        # Dynamic Class Weights
        alpha = torch.FloatTensor(class_weights * params['alpha_scale']).to(DEVICE)
        criterion = FocalLoss(gamma=params['focal_gamma'], alpha=alpha)
        
        # Training (with minimal logging for speed)
        best_val_f1 = 0 
        patience = 12
        cur_patience = 0
        
        for epoch in range(300): # Reduced max epochs for tuning speed
            encoder_r.train(); encoder_m.train(); encoder_c.train(); fusion.train()
            
            _, _, zr, _ = encoder_r(t_r_tr, noise_level=params['noise_level'], noise_type='uniform')
            _, _, zm, _ = encoder_m(t_m_tr, noise_level=params['noise_level'], noise_type='uniform')
            _, _, zc, _ = encoder_c(t_c_tr, noise_level=params['noise_level'], noise_type='uniform')
            
            logits, _, _ = fusion(zr, zm, zc, apply_dropout=True)
            loss = criterion(logits, t_y_tr)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            # Validation
            # Only validate every 5 epochs to save time, or use early stopping
            encoder_r.eval(); encoder_m.eval(); encoder_c.eval(); fusion.eval()
            with torch.no_grad():
                _, _, zr_v, _ = encoder_r(t_r_val)
                _, _, zm_v, _ = encoder_m(t_m_val)
                _, _, zc_v, _ = encoder_c(t_c_val)
                logits_v, _, _ = fusion(zr_v, zm_v, zc_v)
                
                preds = logits_v.argmax(dim=1).cpu().numpy()
                targets = t_y_val.cpu().numpy()
                val_f1 = f1_score(targets, preds, average='macro')
                
            if val_f1 > best_val_f1:
                best_val_f1 = val_f1
                cur_patience = 0
            else:
                cur_patience += 1

            if cur_patience >= patience:
                break
        
        fold_f1s.append(best_val_f1)
        
    return np.mean(fold_f1s)

# %%
# --- LOAD DATA ---
rna_df, meth_df, cnv_df, Y, class_names, class_weights = load_raw_aligned_data()

# --- RUN OPTUNA ---
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100) # Run 100 trials

print("\n>>> OPTIMIZATION COMPLETE")
print("Best F1-Macro:", study.best_value)
print("Best Params:", study.best_params)

# Save Best Params
best_params_df = pd.DataFrame([study.best_params])
best_params_df.to_csv("optuna_best_params_supervised.csv", index=False)
print("Saved optimized parameters to 'optuna_best_params_supervised.csv'")
# Out:
# >>> LOADING RAW ALIGNED DATA
#   Common Samples: 205
# [I 2026-01-23 18:09:09,411] A new study created in memory with name: no-name-fb274dbd-444a-495c-a707-181a6d902ef3
# [I 2026-01-23 18:09:28,997] Trial 0 finished with value: 0.5695099461304622 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.40362176078070056, 'dropout_rate': 0.43082778687563517, 'lr_fine': 2.2113894361097093e-05, 'weight_decay': 0.00022506985404188292, 'noise_level': 0.13155182452970748, 'focal_gamma': 4.631829449008492, 'alpha_scale': 2.0236725688081725}. Best is trial 0 with value: 0.5695099461304622.
# [I 2026-01-23 18:09:40,023] Trial 1 finished with value: 0.7111942548049359 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.14594816520542891, 'dropout_rate': 0.10050371289159227, 'lr_fine': 0.0003749958379909411, 'weight_decay': 0.0003148727697317011, 'noise_level': 0.23549185363982086, 'focal_gamma': 1.9232770876021124, 'alpha_scale': 2.517877541310929}. Best is trial 1 with value: 0.7111942548049359.
# [I 2026-01-23 18:09:51,991] Trial 2 finished with value: 0.4315476125086802 and parameters: {'latent_dim': 32, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.2148528388361274, 'dropout_rate': 0.39665765222081784, 'lr_fine': 1.6981651067007008e-05, 'weight_decay': 0.0008349297574012234, 'noise_level': 0.22820699254289134, 'focal_gamma': 1.8374632384813885, 'alpha_scale': 1.041232095889984}. Best is trial 1 with value: 0.7111942548049359.
# [I 2026-01-23 18:10:05,080] Trial 3 finished with value: 0.5975933129270644 and parameters: {'latent_dim': 24, 'hidden_dim': 96, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.3231726454943926, 'dropout_rate': 0.41579759701086005, 'lr_fine': 2.7658044366990887e-05, 'weight_decay': 0.0009030861587686025, 'noise_level': 0.038708340112227, 'focal_gamma': 3.6605254482988077, 'alpha_scale': 2.622406535077586}. Best is trial 1 with value: 0.7111942548049359.
# [I 2026-01-23 18:10:17,365] Trial 4 finished with value: 0.5621554979032187 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.2944994570731263, 'dropout_rate': 0.24010307152748692, 'lr_fine': 1.2715486668086248e-05, 'weight_decay': 2.2297952510769596e-05, 'noise_level': 0.05580207124677481, 'focal_gamma': 1.3850436756660507, 'alpha_scale': 2.438945513405611}. Best is trial 1 with value: 0.7111942548049359.
# [I 2026-01-23 18:10:28,414] Trial 5 finished with value: 0.5958812927834667 and parameters: {'latent_dim': 24, 'hidden_dim': 96, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.24156023983630048, 'dropout_rate': 0.34117284637032436, 'lr_fine': 0.00012592660928383405, 'weight_decay': 7.80840722697869e-05, 'noise_level': 0.18175315175666068, 'focal_gamma': 4.7595969650901, 'alpha_scale': 2.97714591727836}. Best is trial 1 with value: 0.7111942548049359.
# [I 2026-01-23 18:10:39,403] Trial 6 finished with value: 0.5992442061751874 and parameters: {'latent_dim': 32, 'hidden_dim': 96, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.4660955170480404, 'dropout_rate': 0.45123541166062, 'lr_fine': 0.00011887604453163233, 'weight_decay': 3.781601677434466e-05, 'noise_level': 0.24967195986425036, 'focal_gamma': 2.1327551181878524, 'alpha_scale': 2.2912076864805}. Best is trial 1 with value: 0.7111942548049359.
# [I 2026-01-23 18:10:50,193] Trial 7 finished with value: 0.7242825865368436 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.1896870431274077, 'dropout_rate': 0.47656051161007407, 'lr_fine': 0.0008488229270997493, 'weight_decay': 1.0234892404928133e-05, 'noise_level': 0.21569851147182617, 'focal_gamma': 4.551431436194954, 'alpha_scale': 2.499966661331818}. Best is trial 7 with value: 0.7242825865368436.
# [I 2026-01-23 18:11:01,618] Trial 8 finished with value: 0.46963384349625253 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.3466298960687195, 'dropout_rate': 0.3540048975187998, 'lr_fine': 2.5523093898428945e-05, 'weight_decay': 1.3687328473152643e-05, 'noise_level': 0.29852378959441295, 'focal_gamma': 1.351933850870613, 'alpha_scale': 1.8897942774478935}. Best is trial 7 with value: 0.7242825865368436.
# [I 2026-01-23 18:11:12,561] Trial 9 finished with value: 0.28606590954835276 and parameters: {'latent_dim': 48, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.25746206938427074, 'dropout_rate': 0.4181254201488095, 'lr_fine': 1.0397323442936472e-05, 'weight_decay': 2.2012284156874976e-05, 'noise_level': 0.24474199795988658, 'focal_gamma': 1.2471535159081775, 'alpha_scale': 2.369731587154706}. Best is trial 7 with value: 0.7242825865368436.
# [I 2026-01-23 18:11:24,117] Trial 10 finished with value: 0.7377565911850472 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.11971480377770789, 'dropout_rate': 0.23344684596254933, 'lr_fine': 0.000996577063490702, 'weight_decay': 1.0625663649259493e-05, 'noise_level': 0.12420808926119878, 'focal_gamma': 3.5552602644328815, 'alpha_scale': 1.4805768007823448}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:11:35,648] Trial 11 finished with value: 0.7086331450359844 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.10643518286210078, 'dropout_rate': 0.24746843992559084, 'lr_fine': 0.0007316869326505647, 'weight_decay': 1.1929707064377807e-05, 'noise_level': 0.11872772051440393, 'focal_gamma': 3.7463998164394754, 'alpha_scale': 1.3348180336782167}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:11:46,658] Trial 12 finished with value: 0.7370541415106633 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.17046393243991903, 'dropout_rate': 0.17359394782826196, 'lr_fine': 0.0008767080290126076, 'weight_decay': 5.697228899849809e-05, 'noise_level': 0.1711460537029154, 'focal_gamma': 3.9433657626070984, 'alpha_scale': 1.5918031524896894}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:11:57,590] Trial 13 finished with value: 0.6921238252488251 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.10484753131506457, 'dropout_rate': 0.14337183885821225, 'lr_fine': 0.0003308500380483931, 'weight_decay': 6.636939912487572e-05, 'noise_level': 0.07778230610272518, 'focal_gamma': 3.1050042201114803, 'alpha_scale': 1.5465523839662711}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:12:08,931] Trial 14 finished with value: 0.6542653073771587 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.18087921836812268, 'dropout_rate': 0.1963681039107973, 'lr_fine': 0.00034959300477231057, 'weight_decay': 0.00015185795205253745, 'noise_level': 0.1674141727332146, 'focal_gamma': 3.9237723206699555, 'alpha_scale': 1.6602592263228855}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:12:20,530] Trial 15 finished with value: 0.7086444624496516 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.1523318778584143, 'dropout_rate': 0.26673492011515076, 'lr_fine': 0.0009364020214935897, 'weight_decay': 4.261953106410306e-05, 'noise_level': 0.09596470147726377, 'focal_gamma': 2.914615806150795, 'alpha_scale': 1.1844483716280745}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:12:31,802] Trial 16 finished with value: 0.6269508693347703 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.14710799698500646, 'dropout_rate': 0.18177540032026898, 'lr_fine': 4.8530904680851755e-05, 'weight_decay': 3.0524861450136086e-05, 'noise_level': 0.17652441107381303, 'focal_gamma': 3.0121649634759975, 'alpha_scale': 1.5196903281519807}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:12:43,004] Trial 17 finished with value: 0.6987373025164113 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.10113588037163455, 'dropout_rate': 0.30284454943215183, 'lr_fine': 0.00023387479341532947, 'weight_decay': 0.00014318587798153515, 'noise_level': 0.017302972532456773, 'focal_gamma': 4.0819940783487825, 'alpha_scale': 1.8068928530501327}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:12:53,781] Trial 18 finished with value: 0.7000906039045425 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.26928198736661, 'dropout_rate': 0.19439275564040795, 'lr_fine': 0.0005105817224953626, 'weight_decay': 0.0004762516019722653, 'noise_level': 0.13443732899954897, 'focal_gamma': 3.345140200029371, 'alpha_scale': 2.057082344513443}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:13:04,848] Trial 19 finished with value: 0.643129550325842 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.21435095393159503, 'dropout_rate': 0.1390176335578061, 'lr_fine': 0.00020176025197330883, 'weight_decay': 5.680273355834789e-05, 'noise_level': 0.19889121260330214, 'focal_gamma': 2.7039958311086405, 'alpha_scale': 1.326566106707792}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:13:15,802] Trial 20 finished with value: 0.6570427608957021 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.37016800171009717, 'dropout_rate': 0.28545247287470094, 'lr_fine': 7.020429336073709e-05, 'weight_decay': 0.0001247806515296903, 'noise_level': 0.10229660897836457, 'focal_gamma': 4.272127427855804, 'alpha_scale': 1.3737484037206023}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:13:26,662] Trial 21 finished with value: 0.7153745507674367 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.19102800046733537, 'dropout_rate': 0.48804006263952826, 'lr_fine': 0.0006209706087153907, 'weight_decay': 1.5536957812097578e-05, 'noise_level': 0.20679754743019918, 'focal_gamma': 4.391822239870218, 'alpha_scale': 2.725074807550862}. Best is trial 10 with value: 0.7377565911850472.
# [I 2026-01-23 18:13:37,805] Trial 22 finished with value: 0.7512250703358113 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.1672663229914869, 'dropout_rate': 0.2165155287516396, 'lr_fine': 0.0008913007260408102, 'weight_decay': 1.996022064517201e-05, 'noise_level': 0.15747338809628436, 'focal_gamma': 4.94639288914501, 'alpha_scale': 1.7200162225861244}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:13:48,815] Trial 23 finished with value: 0.6879492881273067 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.14291433996041117, 'dropout_rate': 0.22507284528352742, 'lr_fine': 0.0004816461402496731, 'weight_decay': 2.0145439147076882e-05, 'noise_level': 0.15534847038173782, 'focal_gamma': 4.889696709794031, 'alpha_scale': 1.723652644836402}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:14:00,362] Trial 24 finished with value: 0.6960917840329605 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.22538574387877824, 'dropout_rate': 0.16352056163638842, 'lr_fine': 0.0009833680418886142, 'weight_decay': 3.125953635811877e-05, 'noise_level': 0.1436136293150059, 'focal_gamma': 3.3710951951639068, 'alpha_scale': 1.5431283735706725}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:14:11,792] Trial 25 finished with value: 0.6987233550333395 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.17241385192704103, 'dropout_rate': 0.21906593630109245, 'lr_fine': 0.00020498125560303905, 'weight_decay': 1.7109674363330753e-05, 'noise_level': 0.10513858844798206, 'focal_gamma': 4.956953750847196, 'alpha_scale': 1.9697773419471742}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:14:22,956] Trial 26 finished with value: 0.700573883368001 and parameters: {'latent_dim': 48, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.13309021390319556, 'dropout_rate': 0.12325956449861264, 'lr_fine': 0.0005941858924058317, 'weight_decay': 5.181046448404322e-05, 'noise_level': 0.27447469533672586, 'focal_gamma': 2.4438282981459736, 'alpha_scale': 2.150956048112535}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:14:33,674] Trial 27 finished with value: 0.6727619867674889 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.19313411394550684, 'dropout_rate': 0.3157024984535789, 'lr_fine': 0.0004420824739832967, 'weight_decay': 2.4298263065439925e-05, 'noise_level': 0.18408483261244038, 'focal_gamma': 3.4743147603569633, 'alpha_scale': 1.6715630046643186}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:14:44,512] Trial 28 finished with value: 0.7055946294797417 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.2766549652854896, 'dropout_rate': 0.16086573966762907, 'lr_fine': 0.00028282134157440087, 'weight_decay': 9.266811648635964e-05, 'noise_level': 0.07061580683575663, 'focal_gamma': 4.051569220031055, 'alpha_scale': 1.1450405185449686}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:14:55,562] Trial 29 finished with value: 0.706682887661687 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.43293195028531173, 'dropout_rate': 0.26719916475220357, 'lr_fine': 0.0006714410900989438, 'weight_decay': 1.126308930796592e-05, 'noise_level': 0.15439361528603862, 'focal_gamma': 4.424084007941224, 'alpha_scale': 1.4662657316344836}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:15:06,620] Trial 30 finished with value: 0.6915764718411777 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.12948982098137996, 'dropout_rate': 0.20505677289534543, 'lr_fine': 0.0001609621000797428, 'weight_decay': 0.00020972425396471997, 'noise_level': 0.12425835927908355, 'focal_gamma': 4.664976476565064, 'alpha_scale': 1.8355843040538815}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:15:17,948] Trial 31 finished with value: 0.7099501800043595 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.17071278100138887, 'dropout_rate': 0.17409425363042194, 'lr_fine': 0.0009422279369384393, 'weight_decay': 1.0154093449432152e-05, 'noise_level': 0.20889110380626358, 'focal_gamma': 4.504200059941474, 'alpha_scale': 2.2031639577950997}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:15:28,802] Trial 32 finished with value: 0.7025937877795462 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.20813316188597383, 'dropout_rate': 0.10403315420881815, 'lr_fine': 0.0007557190170604872, 'weight_decay': 1.0023889443125834e-05, 'noise_level': 0.22747569656773017, 'focal_gamma': 4.249527980754246, 'alpha_scale': 2.03154703710597}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:15:39,787] Trial 33 finished with value: 0.7016723091723092 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.16753110847650882, 'dropout_rate': 0.4995115838642267, 'lr_fine': 0.0009937531987234893, 'weight_decay': 1.590756268321174e-05, 'noise_level': 0.195723146296624, 'focal_gamma': 3.8052145217711573, 'alpha_scale': 1.6713212831335569}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:15:50,668] Trial 34 finished with value: 0.7035372501894239 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.12279902228522209, 'dropout_rate': 0.3810918099352224, 'lr_fine': 0.00044550177461199315, 'weight_decay': 2.8673121018297174e-05, 'noise_level': 0.1625989102807953, 'focal_gamma': 4.666305035722478, 'alpha_scale': 1.2321920809525067}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:16:01,343] Trial 35 finished with value: 0.6882637903561817 and parameters: {'latent_dim': 48, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.23705906927240705, 'dropout_rate': 0.4598317787630263, 'lr_fine': 0.0007703480406038109, 'weight_decay': 1.7776783375220812e-05, 'noise_level': 0.14015832829618008, 'focal_gamma': 3.52501090196005, 'alpha_scale': 2.8211873046347624}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:16:12,252] Trial 36 finished with value: 0.7279992449487335 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.20453526189941945, 'dropout_rate': 0.242645224175768, 'lr_fine': 0.0005596555859874679, 'weight_decay': 1.3688258053895088e-05, 'noise_level': 0.21745807339129397, 'focal_gamma': 4.128337792481815, 'alpha_scale': 2.5640698549777783}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:16:23,421] Trial 37 finished with value: 0.7215544301996045 and parameters: {'latent_dim': 24, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.29784762219605265, 'dropout_rate': 0.24390053220099628, 'lr_fine': 0.0005343177847718424, 'weight_decay': 3.994320014773026e-05, 'noise_level': 0.1876470039190141, 'focal_gamma': 4.07896548752984, 'alpha_scale': 1.4237377574454386}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:16:34,727] Trial 38 finished with value: 0.6633188867306514 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.15425943134810507, 'dropout_rate': 0.22268024536959383, 'lr_fine': 0.00037521048344196903, 'weight_decay': 1.3499929568984977e-05, 'noise_level': 0.22062572270795397, 'focal_gamma': 3.612221120013461, 'alpha_scale': 1.0564381863786427}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:16:46,330] Trial 39 finished with value: 0.619278119756061 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.20117020897596405, 'dropout_rate': 0.2608455248966562, 'lr_fine': 4.482836813361562e-05, 'weight_decay': 0.00040954692171631156, 'noise_level': 0.12089871003256984, 'focal_gamma': 3.8909710408846774, 'alpha_scale': 2.6145164979390003}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:16:57,007] Trial 40 finished with value: 0.7133797526299127 and parameters: {'latent_dim': 32, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.24935669201566707, 'dropout_rate': 0.3290322391717103, 'lr_fine': 0.0006229995106693847, 'weight_decay': 2.4900163603777876e-05, 'noise_level': 0.25388687850462144, 'focal_gamma': 3.1931344443444947, 'alpha_scale': 2.969782748021937}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:17:07,660] Trial 41 finished with value: 0.704436190651361 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.12443211206114413, 'dropout_rate': 0.21100279051379534, 'lr_fine': 0.0007108307374688423, 'weight_decay': 1.3146945761339053e-05, 'noise_level': 0.2677743755880117, 'focal_gamma': 4.99295345672575, 'alpha_scale': 2.4141393198634096}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:17:18,864] Trial 42 finished with value: 0.6962656336495346 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.16365783855525137, 'dropout_rate': 0.23443046557797428, 'lr_fine': 0.0007969301381997388, 'weight_decay': 1.9503798868330804e-05, 'noise_level': 0.21903046105516688, 'focal_gamma': 4.527967916066051, 'alpha_scale': 2.573599643364011}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:17:29,883] Trial 43 finished with value: 0.7384153691003537 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.22532963022920569, 'dropout_rate': 0.2904954006486511, 'lr_fine': 0.0008436204263003663, 'weight_decay': 1.497796592656673e-05, 'noise_level': 0.1722566263851087, 'focal_gamma': 4.757105744883276, 'alpha_scale': 2.4988229128901445}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:17:41,335] Trial 44 finished with value: 0.7194664457203157 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.49949192877897036, 'dropout_rate': 0.2790704915008172, 'lr_fine': 0.0005616138807543598, 'weight_decay': 1.538235642795892e-05, 'noise_level': 0.17228432718226602, 'focal_gamma': 4.741104128669979, 'alpha_scale': 2.7384997481671163}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:17:52,450] Trial 45 finished with value: 0.6890619536052972 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.23022228679002943, 'dropout_rate': 0.25070908999494135, 'lr_fine': 0.00038848379605063775, 'weight_decay': 2.321673442224936e-05, 'noise_level': 0.14837761206772054, 'focal_gamma': 4.226842120601675, 'alpha_scale': 2.345560593001574}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:18:03,602] Trial 46 finished with value: 0.6953164762546914 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.21687280532038075, 'dropout_rate': 0.2852684113608067, 'lr_fine': 0.00029846159585300623, 'weight_decay': 3.486592205770227e-05, 'noise_level': 0.16597106528545, 'focal_gamma': 4.807567662831279, 'alpha_scale': 1.601401271101626}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:18:14,902] Trial 47 finished with value: 0.7061107622316231 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3254179399260532, 'dropout_rate': 0.37104703756327023, 'lr_fine': 0.0007905896029389993, 'weight_decay': 1.1925369498509494e-05, 'noise_level': 0.07999918577991201, 'focal_gamma': 3.7124089922585664, 'alpha_scale': 2.495626468368702}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:18:26,208] Trial 48 finished with value: 0.6538606551225278 and parameters: {'latent_dim': 16, 'hidden_dim': 96, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.1153802923930223, 'dropout_rate': 0.18652491549944872, 'lr_fine': 9.110830819513725e-05, 'weight_decay': 4.600888536295176e-05, 'noise_level': 0.24211895028102326, 'focal_gamma': 4.330794192018521, 'alpha_scale': 1.7597760088281598}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:18:37,361] Trial 49 finished with value: 0.7487902412512051 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.18295664131853423, 'dropout_rate': 0.3027030442916708, 'lr_fine': 0.000987703613338516, 'weight_decay': 6.93475083608114e-05, 'noise_level': 0.19169127753988618, 'focal_gamma': 1.5543186688633925, 'alpha_scale': 1.9083575417990937}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:18:48,283] Trial 50 finished with value: 0.7211042578689637 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.14236182264084635, 'dropout_rate': 0.3086143676051741, 'lr_fine': 0.0008529854599180161, 'weight_decay': 7.384393183901104e-05, 'noise_level': 0.19042694301733953, 'focal_gamma': 1.9916504337494707, 'alpha_scale': 1.9492428640329948}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:18:59,395] Trial 51 finished with value: 0.6933842118493821 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.18265332740540027, 'dropout_rate': 0.3416601623582419, 'lr_fine': 0.0006611316827942114, 'weight_decay': 6.439810316867863e-05, 'noise_level': 0.1786340693669904, 'focal_gamma': 1.0456505076486493, 'alpha_scale': 2.1462828160368677}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:19:10,494] Trial 52 finished with value: 0.7226911269558329 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.19869332703536413, 'dropout_rate': 0.29486713678877785, 'lr_fine': 0.0009512076437654311, 'weight_decay': 0.000212604824340424, 'noise_level': 0.20508864339591024, 'focal_gamma': 1.504710395969194, 'alpha_scale': 1.860808639710186}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:19:21,509] Trial 53 finished with value: 0.6735154490071034 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.26111519901411484, 'dropout_rate': 0.26979846989780354, 'lr_fine': 0.0005301723938060043, 'weight_decay': 0.00011193072276311983, 'noise_level': 0.13477218940419283, 'focal_gamma': 1.5906658903693733, 'alpha_scale': 2.2496148503924442}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:19:32,713] Trial 54 finished with value: 0.7054788299076226 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.1582866344908466, 'dropout_rate': 0.23524569753655186, 'lr_fine': 0.0008025565045114526, 'weight_decay': 9.163289327717554e-05, 'noise_level': 0.1622007039920421, 'focal_gamma': 2.8082087932854685, 'alpha_scale': 1.9121102298239083}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:19:44,269] Trial 55 finished with value: 0.7102346999405824 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.18022314265664294, 'dropout_rate': 0.20023964375356784, 'lr_fine': 0.0006575611467869299, 'weight_decay': 2.5935652560353157e-05, 'noise_level': 0.1768950906782436, 'focal_gamma': 2.4413030269856293, 'alpha_scale': 1.6045744354325382}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:19:55,735] Trial 56 finished with value: 0.628124674042698 and parameters: {'latent_dim': 24, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.14085081277970463, 'dropout_rate': 0.33019858583469786, 'lr_fine': 1.902706332439029e-05, 'weight_decay': 0.00017003446134790934, 'noise_level': 0.11470615630075987, 'focal_gamma': 4.018278276881279, 'alpha_scale': 1.7560855851177164}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:20:06,790] Trial 57 finished with value: 0.7001979771391535 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.22216234250938832, 'dropout_rate': 0.25716110529794145, 'lr_fine': 0.0004310291305124519, 'weight_decay': 2.0021802272903537e-05, 'noise_level': 0.14978038579229846, 'focal_gamma': 3.8727746223279897, 'alpha_scale': 1.5006183565001725}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:20:17,841] Trial 58 finished with value: 0.7131963948546953 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.2797469097508291, 'dropout_rate': 0.14182921482561245, 'lr_fine': 0.00084287519845654, 'weight_decay': 1.3715640337921117e-05, 'noise_level': 0.19990133762921247, 'focal_gamma': 4.133167439615716, 'alpha_scale': 1.4001094818274402}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:20:29,027] Trial 59 finished with value: 0.7292380183050191 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.2463405573839386, 'dropout_rate': 0.17584137085215126, 'lr_fine': 0.0009820865301956106, 'weight_decay': 3.38293711841703e-05, 'noise_level': 0.042863949105066496, 'focal_gamma': 3.190825976105731, 'alpha_scale': 1.2936784971827875}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:20:40,273] Trial 60 finished with value: 0.6930091601543008 and parameters: {'latent_dim': 16, 'hidden_dim': 96, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.3122420914199386, 'dropout_rate': 0.16835870193080718, 'lr_fine': 0.0009980153414689077, 'weight_decay': 6.034605662752058e-05, 'noise_level': 0.04561993814218372, 'focal_gamma': 3.2465786648913, 'alpha_scale': 1.6050630808616506}. Best is trial 22 with value: 0.7512250703358113.
# [I 2026-01-23 18:20:51,639] Trial 61 finished with value: 0.7521362688599531 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.2489559573717136, 'dropout_rate': 0.15494309663339426, 'lr_fine': 0.0005699709982203541, 'weight_decay': 3.4314344992889817e-05, 'noise_level': 0.009569949320985566, 'focal_gamma': 3.0634902460826527, 'alpha_scale': 1.3640503465826477}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:21:02,842] Trial 62 finished with value: 0.7333295264177617 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.24252418063198472, 'dropout_rate': 0.12444524191542586, 'lr_fine': 0.000687616466439487, 'weight_decay': 4.561573691533751e-05, 'noise_level': 0.009720382861349908, 'focal_gamma': 3.106824846992666, 'alpha_scale': 1.3141078064756393}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:21:14,291] Trial 63 finished with value: 0.7204071773828806 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.24006463648348966, 'dropout_rate': 0.12196977980764438, 'lr_fine': 0.0006913171571325346, 'weight_decay': 4.990033464431493e-05, 'noise_level': 0.00028977941892865955, 'focal_gamma': 3.00076895080414, 'alpha_scale': 1.232952779981621}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:21:25,349] Trial 64 finished with value: 0.6680099080019157 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.28181458001456194, 'dropout_rate': 0.15285015156540627, 'lr_fine': 0.0004839733398272957, 'weight_decay': 4.165516152165719e-05, 'noise_level': 0.028444779408363905, 'focal_gamma': 2.5724125528693182, 'alpha_scale': 1.479153145829015}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:21:36,050] Trial 65 finished with value: 0.7241870704638236 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.2629786218593433, 'dropout_rate': 0.1257082162510681, 'lr_fine': 0.0008801279102278381, 'weight_decay': 7.798239506526343e-05, 'noise_level': 0.006293378921464682, 'focal_gamma': 2.9010670173743485, 'alpha_scale': 1.0987240314338913}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:21:46,945] Trial 66 finished with value: 0.7094492544492544 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.18293033310429035, 'dropout_rate': 0.1028037589967701, 'lr_fine': 0.0005867183370746285, 'weight_decay': 2.8235296602079214e-05, 'noise_level': 0.01840930318105418, 'focal_gamma': 3.453237928468809, 'alpha_scale': 1.3438233916838678}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:21:57,961] Trial 67 finished with value: 0.697341948526159 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.11154947257375186, 'dropout_rate': 0.15610443765714827, 'lr_fine': 0.0007723284513722036, 'weight_decay': 3.718902957465579e-05, 'noise_level': 0.05372363252779422, 'focal_gamma': 3.3403326243338025, 'alpha_scale': 1.439660160065253}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:22:09,397] Trial 68 finished with value: 0.7082586259056847 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.22516094242573811, 'dropout_rate': 0.13355690590105865, 'lr_fine': 0.00032490857646902367, 'weight_decay': 5.120090112533433e-05, 'noise_level': 0.02911926568051328, 'focal_gamma': 2.3268734672889377, 'alpha_scale': 1.2495220466979655}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:22:21,072] Trial 69 finished with value: 0.45225456326942937 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.1924685026888455, 'dropout_rate': 0.18621793275344498, 'lr_fine': 1.3319310557823412e-05, 'weight_decay': 9.93629789230073e-05, 'noise_level': 0.09080532585595362, 'focal_gamma': 2.6818455167950566, 'alpha_scale': 1.5736206400161445}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:22:32,223] Trial 70 finished with value: 0.7213261759179783 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.253639900257626, 'dropout_rate': 0.21029434028381805, 'lr_fine': 0.0006350822507022115, 'weight_decay': 6.810571544093147e-05, 'noise_level': 0.06591039422453414, 'focal_gamma': 3.6289870637011092, 'alpha_scale': 1.7048642309162347}. Best is trial 61 with value: 0.7521362688599531.
# [I 2026-01-23 18:22:43,557] Trial 71 finished with value: 0.7572517751929516 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.24197886772793253, 'dropout_rate': 0.16933012406900552, 'lr_fine': 0.0009042273587167093, 'weight_decay': 3.459005988439526e-05, 'noise_level': 0.015467437742804966, 'focal_gamma': 3.256789014368607, 'alpha_scale': 1.2976090400518705}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:22:54,860] Trial 72 finished with value: 0.7035143279493125 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.23475419284722235, 'dropout_rate': 0.14884638175758952, 'lr_fine': 0.0007187043949551415, 'weight_decay': 5.783819926846016e-05, 'noise_level': 0.01035665805051757, 'focal_gamma': 3.0833795594536864, 'alpha_scale': 1.148898943809679}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:23:06,203] Trial 73 finished with value: 0.7144445892271979 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.20681991671212077, 'dropout_rate': 0.1938332002347394, 'lr_fine': 0.0008756668383583582, 'weight_decay': 3.055519818190182e-05, 'noise_level': 0.025128170546497977, 'focal_gamma': 2.8378230627446728, 'alpha_scale': 1.293448890329985}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:23:17,257] Trial 74 finished with value: 0.7171561024115204 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.17004043515170048, 'dropout_rate': 0.1095689667754562, 'lr_fine': 0.00048216636621204037, 'weight_decay': 1.7732094664868198e-05, 'noise_level': 0.03796286509005313, 'focal_gamma': 3.3213792485936, 'alpha_scale': 1.3756072109661506}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:23:28,427] Trial 75 finished with value: 0.6826971009726428 and parameters: {'latent_dim': 32, 'hidden_dim': 128, 'fusion_hidden_dim': 32, 'dropout_encoder': 0.21336577101399407, 'dropout_rate': 0.16824267612091676, 'lr_fine': 0.0007060643623131446, 'weight_decay': 4.583853317826342e-05, 'noise_level': 0.016073370505894753, 'focal_gamma': 4.839542005138795, 'alpha_scale': 1.547164762665}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:23:39,269] Trial 76 finished with value: 0.7110078652358064 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.289575615338549, 'dropout_rate': 0.22547595330521897, 'lr_fine': 0.0008919705043297274, 'weight_decay': 0.0007839761937600995, 'noise_level': 0.12673652091974535, 'focal_gamma': 3.556095830994664, 'alpha_scale': 1.7984960547725728}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:23:50,618] Trial 77 finished with value: 0.72738779260653 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.15514622468380376, 'dropout_rate': 0.17998457900222856, 'lr_fine': 0.00041995919201047926, 'weight_decay': 2.2194350463589466e-05, 'noise_level': 0.15845826437560936, 'focal_gamma': 3.084219593907683, 'alpha_scale': 1.002874509690954}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:24:01,912] Trial 78 finished with value: 0.6882186278646099 and parameters: {'latent_dim': 16, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.10021718985043421, 'dropout_rate': 0.31788631413403784, 'lr_fine': 0.00024885344121019137, 'weight_decay': 3.371005823658031e-05, 'noise_level': 0.0017773983611345558, 'focal_gamma': 3.470260276276857, 'alpha_scale': 1.6605521259976377}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:24:13,566] Trial 79 finished with value: 0.6474292226091761 and parameters: {'latent_dim': 16, 'hidden_dim': 128, 'fusion_hidden_dim': 48, 'dropout_encoder': 0.175596536571699, 'dropout_rate': 0.11870393134714334, 'lr_fine': 4.81374009585885e-05, 'weight_decay': 1.1326648878885112e-05, 'noise_level': 0.1864944999734087, 'focal_gamma': 4.602086165490497, 'alpha_scale': 1.1920702780465795}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:24:25,037] Trial 80 finished with value: 0.7308954178788613 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3752309361881377, 'dropout_rate': 0.13486170356176388, 'lr_fine': 0.000609708338142343, 'weight_decay': 8.722114360249533e-05, 'noise_level': 0.17122590462863257, 'focal_gamma': 3.7504841123827264, 'alpha_scale': 1.5079864481919527}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:24:36,254] Trial 81 finished with value: 0.7098646416293475 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.38149482097591303, 'dropout_rate': 0.1309189602705463, 'lr_fine': 0.0005872955794694359, 'weight_decay': 8.678691241606655e-05, 'noise_level': 0.16713320585512936, 'focal_gamma': 3.8222194225933306, 'alpha_scale': 1.4410527673466724}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:24:47,254] Trial 82 finished with value: 0.6638869156327436 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.26912982492946713, 'dropout_rate': 0.11289664910209493, 'lr_fine': 3.813020356317508e-05, 'weight_decay': 0.00011595055206912967, 'noise_level': 0.17119125387081002, 'focal_gamma': 3.7318595320346226, 'alpha_scale': 2.0847649118818414}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:24:58,442] Trial 83 finished with value: 0.7387266327792906 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3370274546875832, 'dropout_rate': 0.14059968374595383, 'lr_fine': 0.000769151354233342, 'weight_decay': 7.044994001954643e-05, 'noise_level': 0.14430715916320486, 'focal_gamma': 3.2287825156728323, 'alpha_scale': 1.518595842911556}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:25:09,241] Trial 84 finished with value: 0.7452337385611979 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3432456271671545, 'dropout_rate': 0.14534286452631395, 'lr_fine': 0.0007668415483848874, 'weight_decay': 7.328400355474955e-05, 'noise_level': 0.14299028656381157, 'focal_gamma': 3.1928528549764694, 'alpha_scale': 1.305977731990416}. Best is trial 71 with value: 0.7572517751929516.
# [I 2026-01-23 18:25:20,432] Trial 85 finished with value: 0.7620819612446608 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3491289049443652, 'dropout_rate': 0.16068642082813853, 'lr_fine': 0.0008594486291309886, 'weight_decay': 6.76698224752014e-05, 'noise_level': 0.14240255176227967, 'focal_gamma': 3.284467633413383, 'alpha_scale': 1.3616228465045954}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:25:31,412] Trial 86 finished with value: 0.7211485756474989 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3439250570381937, 'dropout_rate': 0.16044724091255444, 'lr_fine': 0.0007751160044260009, 'weight_decay': 6.635522787703587e-05, 'noise_level': 0.1399539394409131, 'focal_gamma': 3.229979937343088, 'alpha_scale': 1.247233649468925}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:25:42,322] Trial 87 finished with value: 0.7392696815568333 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.35355854845012574, 'dropout_rate': 0.29496462618463176, 'lr_fine': 0.0008692634468178301, 'weight_decay': 0.0001325058090966958, 'noise_level': 0.15339148920761367, 'focal_gamma': 1.7648590032590095, 'alpha_scale': 1.3403515556801193}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:25:52,859] Trial 88 finished with value: 0.6725352005124338 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.34844539763972093, 'dropout_rate': 0.35126783950481316, 'lr_fine': 0.0001637945335481611, 'weight_decay': 0.00016805008477525425, 'noise_level': 0.1327884682606959, 'focal_gamma': 1.7237914608118696, 'alpha_scale': 1.3692807487451442}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:26:03,825] Trial 89 finished with value: 0.7080973059626405 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.35673889174557594, 'dropout_rate': 0.14749145561391006, 'lr_fine': 0.0008712632172598729, 'weight_decay': 0.00010765176275436433, 'noise_level': 0.11013542352383893, 'focal_gamma': 1.86902812347612, 'alpha_scale': 1.191119781519275}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:26:14,685] Trial 90 finished with value: 0.7081842876742762 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.36330756283137766, 'dropout_rate': 0.4106090263887377, 'lr_fine': 0.0005378450350426997, 'weight_decay': 0.00014335158806766247, 'noise_level': 0.14477902901733902, 'focal_gamma': 1.2980239075259092, 'alpha_scale': 1.2870673578891128}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:26:25,763] Trial 91 finished with value: 0.7560985935985935 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3909788764652059, 'dropout_rate': 0.29157753403655307, 'lr_fine': 0.0009910132183003045, 'weight_decay': 0.00012578355820869257, 'noise_level': 0.1558403187365997, 'focal_gamma': 2.073001374677241, 'alpha_scale': 1.4071293018297728}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:26:36,337] Trial 92 finished with value: 0.7154197318610019 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.32738587124857577, 'dropout_rate': 0.29782157639673507, 'lr_fine': 0.0009984502706530632, 'weight_decay': 0.00012519721718277615, 'noise_level': 0.15170614627416984, 'focal_gamma': 2.017288343162816, 'alpha_scale': 1.3964919810339533}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:26:47,430] Trial 93 finished with value: 0.6998377095340012 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.4057773265286122, 'dropout_rate': 0.30893907836565326, 'lr_fine': 0.0007654400494469356, 'weight_decay': 0.00029845770780697684, 'noise_level': 0.1550831808103291, 'focal_gamma': 1.6911431612085088, 'alpha_scale': 1.3393608359520384}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:26:58,442] Trial 94 finished with value: 0.718260835163009 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.4013714359363726, 'dropout_rate': 0.2745392035785112, 'lr_fine': 0.0008510516528786378, 'weight_decay': 7.653648793165091e-05, 'noise_level': 0.13746898163766152, 'focal_gamma': 1.4370014601322465, 'alpha_scale': 1.155018415599354}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:27:09,472] Trial 95 finished with value: 0.6985575666163901 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.34139214868389167, 'dropout_rate': 0.2861596670392094, 'lr_fine': 0.0008840085652064307, 'weight_decay': 0.00012445524427394516, 'noise_level': 0.18152273939517372, 'focal_gamma': 2.9252983821221212, 'alpha_scale': 1.088906833948511}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:27:20,010] Trial 96 finished with value: 0.7048423686163625 and parameters: {'latent_dim': 48, 'hidden_dim': 96, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.30559399418967403, 'dropout_rate': 0.32091842549909305, 'lr_fine': 0.0007192301721882158, 'weight_decay': 0.00018047298697069063, 'noise_level': 0.19319527090678063, 'focal_gamma': 2.2099320864966407, 'alpha_scale': 1.4644767483663799}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:27:30,847] Trial 97 finished with value: 0.6958161428591499 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.38845445706230297, 'dropout_rate': 0.2937778478416412, 'lr_fine': 0.0006394699175053582, 'weight_decay': 0.00025473584888016345, 'noise_level': 0.127544574561806, 'focal_gamma': 1.1877166809612079, 'alpha_scale': 1.4156550547584683}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:27:42,165] Trial 98 finished with value: 0.737886952298717 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.333291143373649, 'dropout_rate': 0.33070355262539836, 'lr_fine': 0.0007890167584726201, 'weight_decay': 9.940249724766592e-05, 'noise_level': 0.16047001285052515, 'focal_gamma': 1.7538362664273743, 'alpha_scale': 1.9910398322012801}. Best is trial 85 with value: 0.7620819612446608.
# [I 2026-01-23 18:27:53,040] Trial 99 finished with value: 0.6444450975159273 and parameters: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.31250998005858116, 'dropout_rate': 0.14236978721634824, 'lr_fine': 6.790450532467108e-05, 'weight_decay': 5.3885805285807285e-05, 'noise_level': 0.11567590279483418, 'focal_gamma': 3.396513870688815, 'alpha_scale': 1.531745908301252}. Best is trial 85 with value: 0.7620819612446608.
# >>> OPTIMIZATION COMPLETE
# Best F1-Macro: 0.7620819612446608
# Best Params: {'latent_dim': 48, 'hidden_dim': 128, 'fusion_hidden_dim': 64, 'dropout_encoder': 0.3491289049443652, 'dropout_rate': 0.16068642082813853, 'lr_fine': 0.0008594486291309886, 'weight_decay': 6.76698224752014e-05, 'noise_level': 0.14240255176227967, 'focal_gamma': 3.284467633413383, 'alpha_scale': 1.3616228465045954}
# Saved optimized parameters to 'optuna_best_params_supervised.csv'

# %%
def run_final_evaluation(rna_df, meth_df, cnv_df, Y, class_names, class_weights, params):
    print(f"\n{'='*40}")
    print("STARTING FINAL EVALUATION (Best Params)")
    print(f"{'='*40}")
    
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
    fold_metrics = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(rna_df, Y)):
        print(f"\n--- Fold {fold+1} ---")
        
        t_r_tr, t_r_val, dim_r = prepare_fold_data(rna_df.iloc[train_idx], rna_df.iloc[val_idx])
        t_m_tr, t_m_val, dim_m = prepare_fold_data(meth_df.iloc[train_idx], meth_df.iloc[val_idx])
        t_c_tr, t_c_val, dim_c = prepare_fold_data(cnv_df.iloc[train_idx], cnv_df.iloc[val_idx])
        
        t_y_tr = torch.LongTensor(Y[train_idx]).to(DEVICE)
        t_y_val = torch.LongTensor(Y[val_idx]).to(DEVICE)
        
        encoder_r = PerOmicCMAE(dim_r, params['latent_dim'], params['hidden_dim'], params['dropout_encoder']).to(DEVICE)
        encoder_m = PerOmicCMAE(dim_m, params['latent_dim'], params['hidden_dim'], params['dropout_encoder']).to(DEVICE)
        encoder_c = PerOmicCMAE(dim_c, params['latent_dim'], params['hidden_dim'], params['dropout_encoder']).to(DEVICE)
        fusion = GatedAttentionFusion(params['latent_dim'], len(class_names), params['dropout_rate'], params['hidden_dim']).to(DEVICE)
        
        optimizer = optim.AdamW(
            list(encoder_r.parameters()) + list(encoder_m.parameters()) + 
            list(encoder_c.parameters()) + list(fusion.parameters()),
            lr=params['lr_fine'], weight_decay=params['weight_decay']
        )
        
        alpha = torch.FloatTensor(class_weights * params['alpha_scale']).to(DEVICE)
        criterion = FocalLoss(gamma=params['focal_gamma'], alpha=alpha)
        
        # Mode changed to 'max' to track F1-Macro instead of Loss
        scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=5) 
        
        best_f1 = 0.0
        best_model_states = None
        patience = 20
        cur_pat = 0
        warmup_epochs = 10
        
        for epoch in range(800): 
            # --- WARMUP LOGIC ---
            if epoch < warmup_epochs:
                warmup_lr = params['lr_fine'] * ((epoch + 1) / warmup_epochs)
                for param_group in optimizer.param_groups:
                    param_group['lr'] = warmup_lr

            encoder_r.train(); encoder_m.train(); encoder_c.train(); fusion.train()
            _, _, zr, _ = encoder_r(t_r_tr, noise_level=params['noise_level'], noise_type='uniform')
            _, _, zm, _ = encoder_m(t_m_tr, noise_level=params['noise_level'], noise_type='uniform')
            _, _, zc, _ = encoder_c(t_c_tr, noise_level=params['noise_level'], noise_type='uniform')
            
            logits, _, _ = fusion(zr, zm, zc, apply_dropout=True)
            loss = criterion(logits, t_y_tr)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            # --- VALIDATION (Tracking F1) ---
            encoder_r.eval(); encoder_m.eval(); encoder_c.eval(); fusion.eval()
            with torch.no_grad():
                _, _, zr_v, _ = encoder_r(t_r_val, noise_level=0.0)
                _, _, zm_v, _ = encoder_m(t_m_val, noise_level=0.0)
                _, _, zc_v, _ = encoder_c(t_c_val, noise_level=0.0)
                logits_v, _, _ = fusion(zr_v, zm_v, zc_v)
                
                preds_v = logits_v.argmax(dim=1).cpu().numpy()
                targets_v = t_y_val.cpu().numpy()
                val_f1 = f1_score(targets_v, preds_v, average='macro')

            # Only step the plateau scheduler after warmup finishes
            if epoch >= warmup_epochs:
                scheduler.step(val_f1)
            
            if val_f1 > best_f1:
                best_f1 = val_f1
                cur_pat = 0
                # --- STATE SAVING FIX ---
                best_model_states = {
                    'enc_r': copy.deepcopy(encoder_r.state_dict()),
                    'enc_m': copy.deepcopy(encoder_m.state_dict()),
                    'enc_c': copy.deepcopy(encoder_c.state_dict()),
                    'fusion': copy.deepcopy(fusion.state_dict()),
                    'preds': preds_v,
                    'targets': targets_v
                }
            else:
                cur_pat += 1
            
            if cur_pat >= patience and epoch >= warmup_epochs:
                break
        
        # --- RESTORE BEST WEIGHTS ---
        encoder_r.load_state_dict(best_model_states['enc_r'])
        encoder_m.load_state_dict(best_model_states['enc_m'])
        encoder_c.load_state_dict(best_model_states['enc_c'])
        fusion.load_state_dict(best_model_states['fusion'])
        
        # Calculate Final Metrics using the BEST saved state
        final_targets = best_model_states['targets']
        final_preds = best_model_states['preds']
        
        f1_macro = f1_score(final_targets, final_preds, average='macro')
        f1_micro = f1_score(final_targets, final_preds, average='micro')
        prec = precision_score(final_targets, final_preds, average='macro')
        rec = recall_score(final_targets, final_preds, average='macro')
        acc = accuracy_score(final_targets, final_preds)
        
        print(f"   Fold {fold+1} Result: F1-Macro={f1_macro:.4f}, Acc={acc:.4f}")
        
        fold_metrics.append({
            'Fold': fold + 1,
            'F1_Macro': f1_macro,
            'F1_Micro': f1_micro,
            'Precision_Macro': prec,
            'Recall_Macro': rec,
            'Accuracy': acc
        })
    
    # Aggregate Metrics
    metrics_df = pd.DataFrame(fold_metrics)
    mean_metrics = metrics_df.mean()
    std_metrics = metrics_df.std()
    
    print(f"\n{'='*40}")
    print("FINAL AVERAGED RESULTS (5-Fold CV)")
    print(f"{'='*40}")
    print(f"F1-Macro:       {mean_metrics['F1_Macro']:.4f} (+/- {std_metrics['F1_Macro']:.4f})")
    print(f"F1-Micro:       {mean_metrics['F1_Micro']:.4f} (+/- {std_metrics['F1_Micro']:.4f})")
    print(f"Precision:      {mean_metrics['Precision_Macro']:.4f} (+/- {std_metrics['Precision_Macro']:.4f})")
    print(f"Recall:         {mean_metrics['Recall_Macro']:.4f} (+/- {std_metrics['Recall_Macro']:.4f})")
    print(f"Accuracy:       {mean_metrics['Accuracy']:.4f} (+/- {std_metrics['Accuracy']:.4f})")
    
    metrics_df.to_csv("final_metrics_supervised_optimized.csv", index=False)
    print("\nDetailed metrics saved to 'final_metrics_supervised_optimized.csv'")
